# %%
import random

thelist=[0,1,0]

     # Arkasında hediye olan kapının kod tarafından random belirlenmesi
    
newlist=random.shuffle(thelist)
A=thelist[0]
B=thelist[1]
C=thelist[2]
print("dolu kapı=", newlist)    
    # Yarışmacının tercihinin seçimi
        
choice=input("A, B ve C kapılarından birinin arkasında BÜYÜK HEDİYE var? Sence hangisi? : ")
    
    # Yarışmacının seçiminin değerlendirilmesi ve random olarak seçilen ve arkasında hediye olayan kapının belirlenmesi
removed=[]    
items=[]
if choice=="A" and A==1:
    items=["B","C"]
    
elif choice=="B" and B==1:
    items=["A","C"]
    
elif choice=="C" and C==1:   
    items=["A","B"]
  
        
elif choice=="A" and A==0:
    items=["B","C"]
    if B==1:
        items.remove("B")
        removed.append("C")
    elif C==1:
        items.remove("C")
        removed.append("B")
elif choice=="B" and B==0:
    items=["A","C"]
    if A==1:
        items.remove("A")
        removed.append("C")
    elif C==1:
        items.remove("C")
        removed.append("A")
elif choice=="C" and C==0:
    items=["A","B"]
    if A==1:
        items.remove("A")
        removed.append("B")
    elif B==1:
        items.remove("B")
        removed.append("A")
             
    
        
seclist=["A","B","C"]
seclist.remove(items[0])
    
    
    # Yarışmacıya yeni tercihin sorulması ve ikinci tercihinin random olarak alınması
    
    
text=("Şimdi senin için bir iyilik yapıp seçmediğin iki kapı arasından  boş olan,", removed[0], "açıyorum. Geri seçimini değiştirip", items ,"Kapısını seçmek istermisin? Tercihini yap?" )
    
latestchoice=input(text)
    
win1=2

if latestchoice=="A" and A==1:
       
    win1=1
elif latestchoice=="B" and B==1:
        
    win1=1
elif latestchoice=="C" and C==1:
       
    win1=1
else:
        
    win1=0
